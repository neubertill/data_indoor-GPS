# %%
# !pip install pandas seaborn adjusttext

# %%
import pandas as pd #for working with dataframes
import numpy as np #for numerical and vector operations
import matplotlib as mpl #for visualization
import matplotlib.pyplot as plt #for visualization
import seaborn as sns #for visualization
import os
from adjustText import adjust_text

# %%
df1=pd.read_csv("../Data/Scenario1.csv", sep= ';',header=0)
print(df1)
xR=np.asarray(df1["xR"])
yR=np.asarray(df1["yR"])

xL=np.asarray(df1["xL"])
yL=np.asarray(df1["yL"])

nR=df1["Reference"]
nL=df1["Localino"]
# Out:
#    Localino   xL  yL Reference      xR      yR
# 0       L01 -223   9       R01 -231.15   39.22
# 1       L02 -233   4       R02 -230.35   49.01
# 2       L03 -241   2       R03 -230.56   58.54
# 3       L04 -197  35       R04 -230.27   69.41
# 4       L05 -223 -15       R05 -230.72   78.93
# 5       L06 -218  -7       R06 -230.07   88.67
# 6       L07 -231 -23       R07 -230.60   98.57
# 7       L08 -250 -80       R08 -231.05  107.96
# 8       L09 -219 -81       R09 -220.97  108.00
# 9       L10 -213 -27       R10 -210.68  107.17
# 10      L11 -105 -12       R11 -200.98  107.68
# 11      L12   17  53       R12 -191.04  108.02
# 12      L13 -127 -59       R13 -181.00  107.89
# 13      L14  134  46       R14 -171.01  107.85
# 14      L15  229  63       R15 -161.40  107.51
# 15      L16   51 -14       R16 -151.69  107.67
# 16      L17  -79   0       R17 -150.70   97.80
# 17      L18  187  52       R18 -151.44   87.83
# 18      L19   83  28       R19 -151.58   78.12
# ...

# %%
fig, ax = plt.subplots(figsize=(18,10))
ref=plt.scatter(xR, yR,c='tab:orange')
loc=plt.scatter(xL, yL,c='tab:blue')
plt.grid(True)
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")
plt.xticks([-250,-200,-150,-100,-50,0,50,100,150,200,250])


circle1 = mpl.patches.Ellipse((229, 63), 11*2,8*2, color='r',fill=False)
circle2 = mpl.patches.Ellipse((187, 52), 11*2,8*2, color='r',fill=False)
circle3 = mpl.patches.Ellipse((134, 46), 11*2,8*2, color='r',fill=False)
ax.add_patch(circle1)
ax.add_patch(circle2)
ax.add_patch(circle3)

ax.legend([ref,loc,circle1],['Laser tracker','Indoor GPS','Outlier'],title='Scenario 1')

texts = [plt.text(xR[i], yR[i], nR[i], ha='center', va='center') for i in range(len(xR))]
texts2 = [plt.text(xL[i], yL[i], nL[i], ha='center', va='center') for i in range(len(xL))]
adjust_text(texts+texts2, avoid_self=False)

plt.savefig("Scenario1_fig.png")

# %%
df2=pd.read_csv("../Data/Scenario2.csv", sep= ';',header=0)
print(df2)
xR2=np.asarray(df2["xR"])
yR2=np.asarray(df2["yR"])

xL2=np.asarray(df2["xL"])
yL2=np.asarray(df2["yL"])

nR2=df2["Reference"]
nL2=df2["Localino"]
# Out:
#    Localino   xL   yL Reference      xR      yR
# 0       L01 -227   13       R01 -230.89   38.80
# 1       L02 -263   16       R02 -230.65   49.04
# 2       L03 -238    3       R03 -230.66   58.89
# 3       L04 -245   34       R04 -229.87   69.09
# 4       L05 -237   18       R05 -230.91   78.73
# 5       L06 -246   40       R06 -230.49   88.62
# 6       L07 -239   56       R07 -230.34   99.02
# 7       L08 -242 -127       R08 -231.08  107.77
# 8       L09 -256   61       R09 -220.66  109.34
# 9       L10 -267   89       R10 -210.90  107.71
# 10      L11 -223   35       R11 -200.75  107.96
# 11      L12 -196   71       R12 -190.99  107.96
# 12      L13 -191   38       R13 -180.89  107.81
# 13      L14 -176   60       R14 -170.53  107.72
# 14      L15 -168   84       R15 -160.84  108.58
# 15      L16 -156   59       R16 -150.58  107.60
# 16      L17 -158   55       R17 -151.02   98.02
# 17      L18 -154   56       R18 -152.05   88.36
# 18      L19 -135   69       R19 -151.69   78.48
# ...

# %%
fig, ax = plt.subplots(figsize=(13,10))
ref=plt.scatter(xR2, yR2,c='tab:orange')
loc=plt.scatter(xL2, yL2,c='tab:blue')
plt.grid(True)
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")



circle1 = mpl.patches.Ellipse((-242, -127), 9, 22.5,color='r',fill=False)
circle2 = mpl.patches.Ellipse((-211, -105), 9, 22.5,color='r',fill=False)
ax.add_patch(circle1)
ax.add_patch(circle2)

ax.legend([ref,loc,circle1],['Laser tracker','Indoor GPS', 'Outlier'],loc='lower right',title='Scenario 2')

texts = [plt.text(xR2[i], yR2[i], nR2[i], ha='center', va='center') for i in range(len(xR))]
texts2 = [plt.text(xL2[i], yL2[i], nL2[i], ha='center', va='center') for i in range(len(xL))]
adjust_text(texts+texts2,avoid_self=False)
plt.savefig("Scenario2_fig.png")

# %%
df3=pd.read_csv("../Data/Scenario3.csv", sep= ';',header=0)
print(df3)
xR3=np.asarray(df3["xR"])
yR3=np.asarray(df3["yR"])

xL3=np.asarray(df3["xL"])
yL3=np.asarray(df3["yL"])

nR3=df3["Reference"]
nL3=df3["Localino"]
# Out:
#    Localino   xL   yL Reference      xR      yR
# 0       L01 -227   26       R01 -231.31   38.90
# 1       L02 -227   18       R02 -231.34   48.62
# 2       L03 -222   72       R03 -230.89   58.00
# 3       L04 -226   78       R04 -230.67   68.49
# 4       L05 -230   48       R05 -230.82   77.79
# 5       L06 -235   88       R06 -231.14   88.15
# 6       L07 -234   99       R07 -230.36   97.51
# 7       L08 -236  101       R08 -231.11  107.31
# 8       L09 -226  129       R09 -221.25  107.61
# 9       L10 -211  134       R10 -210.59  107.80
# 10      L11 -203  116       R11 -201.77  107.31
# 11      L12 -189  124       R12 -191.70  107.72
# 12      L13 -179  108       R13 -181.32  107.42
# 13      L14 -169  104       R14 -171.27  108.01
# 14      L15 -156  127       R15 -160.83  107.76
# 15      L16 -145  111       R16 -151.63  107.46
# 16      L17 -147  103       R17 -150.82   98.13
# 17      L18 -143   93       R18 -150.89   87.68
# 18      L19 -139   84       R19 -151.59   78.47
# ...

# %%
fig, ax = plt.subplots(figsize=(13,10))
ref=plt.scatter(xR3, yR3,c='tab:orange')
loc=plt.scatter(xL3, yL3,c='tab:blue')
plt.grid(True)
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")

circle1 = mpl.patches.Ellipse((-142, -8), 6.5, 13,color='r',fill=False)
ax.add_patch(circle1)

ax.legend([ref,loc,circle1],['Laser tracker','Indoor GPS', 'Outlier'],title='Scenario 3')

texts = [plt.text(xR3[i], yR3[i], nR3[i], ha='center', va='center') for i in range(len(xR))]
texts2 = [plt.text(xL3[i], yL3[i], nL3[i], ha='center', va='center') for i in range(len(xL))]
adjust_text(texts+texts2,avoid_self=False)
plt.savefig("Scenario3_fig.png")

# %%
df4=pd.read_csv("../Data/Scenario4.csv", sep= ';',header=0)
print(df4)
xR4=np.asarray(df4["xR"])
yR4=np.asarray(df4["yR"])

xL4=np.asarray(df4["xL"])
yL4=np.asarray(df4["yL"])

nR4=df4["Reference"]
nL4=df4["Localino"]
# Out:
#    Localino   xL   yL Reference      xR      yR
# 0       L01 -229   33       R01 -228.95   40.25
# 1       L02 -229   43       R02 -228.87   50.08
# 2       L03 -222   54       R03 -228.94   59.53
# 3       L04 -225   61       R04 -228.75   69.49
# 4       L05 -224   73       R05 -228.45   79.57
# 5       L06 -222   82       R06 -228.69   88.74
# 6       L07 -223   89       R07 -228.89   98.54
# 7       L08 -231  106       R08 -229.10  109.18
# 8       L09 -223  106       R09 -219.35  109.28
# 9       L10 -213  102       R10 -209.70  109.45
# 10      L11 -199   99       R11 -199.57  109.25
# 11      L12 -189   94       R12 -189.38  109.27
# 12      L13 -179   93       R13 -179.14  109.14
# 13      L14 -175   95       R14 -169.26  109.38
# 14      L15 -160   96       R15 -159.26  109.70
# 15      L16 -150   91       R16 -149.54  109.93
# 16      L17 -147   80       R17 -149.49  100.40
# 17      L18 -149   75       R18 -149.31   90.46
# 18      L19 -149   62       R19 -151.15   80.56
# ...

# %%
fig, ax = plt.subplots(figsize=(13,10))
plt.grid(True)
ref=plt.scatter(xR4, yR4,c='tab:orange')
loc=plt.scatter(xL4, yL4,c='tab:blue')

plt.xlabel("x [cm]")
plt.ylabel("y [cm]")

circle1 = mpl.patches.Ellipse((-150, 32), 6,8,color='r',fill=False)
ax.add_patch(circle1)

ax.legend([ref,loc,circle1],['Laser tracker','Indoor GPS', 'Outlier'],title='Scenario 4')

texts = [plt.text(xR4[i], yR4[i], nR4[i], ha='center', va='center') for i in range(len(xR))]
texts2 = [plt.text(xL4[i], yL4[i], nL4[i], ha='center', va='center') for i in range(len(xL))]
adjust_text(texts+texts2,avoid_self=False)
plt.savefig("Scenario4_fig.png")
